# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
df = pd.read_csv('simulated_error_logs.csv')
df
# Out:
#                             Status_Ts  Active_Errors_Count  \
# 0    2025-06-02T17:22:11.503850+00:00                    0
# 1    2025-06-05T21:39:06.503850+00:00                    1
# 2    2025-06-05T22:52:53.503850+00:00                    0
# 3    2025-06-09T23:26:19.503850+00:00                    1
# 4    2025-06-10T00:03:55.503850+00:00                    0
# ..                                ...                  ...
# 430  2027-09-14T10:30:38.503850+00:00                    0
# 431  2027-09-19T23:46:23.503850+00:00                    1
# 432  2027-09-19T23:57:24.503850+00:00                    0
# 433  2027-09-20T12:12:52.503850+00:00                    1
# 434  2027-09-20T13:39:55.503850+00:00                    2
#
#                             Active_Errors_Details_JSON
# 0                                                   []
# 1    [{'Id': 'f00310b6-1cba-44b5-856c-acf0d2b4015d'...
# 2                                                   []
# ...

# %%
df.describe()
# Out:
#        Active_Errors_Count
# count           435.000000
# mean              0.650575
# std               0.652693
# min               0.000000
# 25%               0.000000
# 50%               1.000000
# 75%               1.000000
# max               3.000000

# %%
df['datetime_object'] = pd.to_datetime(df['Status_Ts'])
df['timestamp'] = df['datetime_object'].astype(int) / 10**9

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['timestamp'], df['Active_Errors_Count'], marker='o', linestyle='-')
plt.title('Erreurs')
plt.xlabel('Timestamp')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_sub = df.head(25)
plt.figure(figsize=(12, 6))
plt.step(df_sub['datetime_object'], df_sub['Active_Errors_Count'], where='post')
plt.title('Erreurs')
plt.xticks([])
plt.yticks([])
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
plt.tight_layout()
plt.show()
